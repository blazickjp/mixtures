# %%
import mixtures
import numpy as np

# %%
# gmm = mixtures.FiniteGMM(4, [0,4,8,16], [1,1,2,3], [.2,.2,.2,.4])
# Define parameters for K=3 Mixture of Multivariate Gaussians
phi = [.3, .5, .2]
mu = np.array([[13,5], [0,-2], [-14,3]])
cov_1 = np.array([[2.0, 0.3], [0.3, 0.5]])
cov_2 = np.array([[3.0,.4], [.4,3.0]])    
cov_3 = np.array([[1.7,-.7], [-.7,1.7]])
cov = np.stack((cov_1, cov_2, cov_3), axis = 0)

gmm = mixtures.FiniteGMM(3, mu, cov, phi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4e20738f9e3b> in <module>
#       2 # Define parameters for K=3 Mixture of Multivariate Gaussians
#       3 phi = [.3, .5, .2]
# ----> 4 mu = np.array([[13,5], [0,-2], [-14,3]])
#       5 cov_1 = np.array([[2.0, 0.3], [0.3, 0.5]])
#       6 cov_2 = np.array([[3.0,.4], [.4,3.0]])
#
# NameError: name 'np' is not defined

# %%
gmm.data_gen(1000)

# %%
gmm.plot_data(alpha = .5)

# %%
gmm.gibbs(iters=500)
# Out:
# {'mu': array([ 0.8 , 12.48,  3.89, -0.15]),
#  'sigma': array([1.47, 5.21, 1.19, 0.99]),
#  'pi': array([0.05, 0.63, 0.19, 0.13])}

# %%
gmm.plot_results(alpha = .5)

# %%
gmm = mixtures.FiniteGMM(4, [0,4,8,16], [1,1,2,3], [.2,.2,.2,.4])
gmm.data_gen(1000)
gmm.plot_data(alpha = .5)

# %%
gmm.gibbs(iters=500)
gmm.plot_results(alpha = .5)
